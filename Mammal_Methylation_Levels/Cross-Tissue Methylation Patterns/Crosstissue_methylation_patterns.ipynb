# %% [markdown]
# # Cross-Tissue Methylation Patterns of Clock CpGS

# %% [markdown]
# This script analyzes methylation patterns across tissues and epigenetic clocks with the following objectives:
#
# 1. Identification of Consistent Methylation Patterns:
#    - High methylation CpGs: Mean methylation > 0.8 across tissues.
#    - Low methylation CpGs: Mean methylation < 0.2 across tissues.
#    - Variable CpGs: Methylation range > 0.1 across tissues.
# 2. Detection of Differentially Methylated CpGs:
#    - Use of one-way ANOVA to identify CpGs with significant differences between tissues (p-value < 0.01).
# 3. Summary Statistics:
#    - Calculation of mean, median, standard deviation, and range of methylation values for each tissue and clock.
# 4. Data Export:
#    - Results are saved in CSV format, including combined statistics, mean methylation profiles, consistent patterns, and ANOVA results.
#
# This analysis provides insights into conserved and variable epigenetic markers, contributing to our understanding of epigenetic regulation across different biological contexts.

# %%
#### LOAD: libraries
import os
import pandas as pd
import numpy as np
import seaborn as sns

import itertools
from itertools import combinations

from pathlib import Path

import matplotlib.cm as cm  
from matplotlib import colormaps as mcolors
import matplotlib.pyplot as plt

from matplotlib import colormaps

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

import pandas as pd
import numpy as np
from scipy import stats
import os
import joblib

from matplotlib_venn import venn3
import matplotlib.pyplot as plt

# %% [markdown]
# ## 0. Load the data

# %%
#### LOAD: Metadata
metadata = pd.read_csv('GSE223748_complete_metadata.csv')

# %%
#### LOAD: Complete methylation data

complete_methylation = pd.read_csv('GSE223748_datBetaNormalized.csv')
complete_methylation.rename(columns={'Unnamed: 0': 'CpG'}, inplace=True)

# %%
#### LOAD: Tissue-specific methylation datasets from the saved CSV files

folder_name = "Tissue Methylation"
tissue_files = os.listdir(folder_name) # Get a list of all files in the folder
tissues_df = metadata[['Sample', 'Tissue']]
tissues = tissues_df['Tissue'].unique() # Get a list of all tissues

# Load each CSV file into its own dataframe
for file in tissue_files:
    if file.endswith("_methylation_dataset.csv"):
        # Extract tissue name from file name
        tissue = file.split("_")[0]

        # Load CSV file into dataframe
        file_path = os.path.join(folder_name, file)
        globals()['{}_methylation_dataset'.format(tissue)] = pd.read_csv(file_path)

# %%
#### LOAD: Methylation data for the complete CpGs of each clock
clock1 = pd.read_csv('./Clocks Methylation Data/Clock1_Methylation_data_complete.csv') 
clock2 = pd.read_csv('./Clocks Methylation Data/Clock2_Methylation_data_complete.csv')
clock3 = pd.read_csv('./Clocks Methylation Data/Clock3_Methylation_data_complete.csv')
# clock2_3 = pd.read_csv('./Clocks Methylation Data/Clock2_3_Overlap_Methylation_data_complete.csv')

# %%
print(f'Total number of CpGs in Clock 1: {len(clock1)}')
print(f'Total number of CpGs in Clock 2: {len(clock2)}')
print(f'Total number of CpGs in Clock 3: {len(clock3)}')
# print(f'Total number of CpGs in Clock 2 & 3 overlap: {len(clock2_3)}')
# Out:
# Total number of CpGs in Clock 1: 335
# Total number of CpGs in Clock 2: 816
# Total number of CpGs in Clock 3: 760

# %%
### Filter the complete methylation dataset by the CpGs in each clock

# Define a function to filter methylation data by CpGs in a given clock
def filter_by_clock(complete_methylation, clock_cpgs):
    return complete_methylation[complete_methylation['CpG'].isin(clock_cpgs)]

# Filter the datasets 
complete_methylation_dataset_clock1_filtered = filter_by_clock(complete_methylation, clock1['CpG'].values)
complete_methylation_dataset_clock2_filtered = filter_by_clock(complete_methylation, clock2['CpG'].values)
complete_methylation_dataset_clock3_filtered = filter_by_clock(complete_methylation, clock3['CpG'].values)
# complete_methylation_dataset_clock2_3_filtered = filter_by_clock(complete_methylation, clock2_3['CpG'].values)

# %%
### Create a dataframe that stores the tissue-specific datasets for each clock

# Filter the all tissue-specific datasets by the CpGs in each clock
clocks = {
    'clock1': clock1['CpG'].values,
    'clock2': clock2['CpG'].values,
    'clock3': clock3['CpG'].values
    # 'clock2_3': clock2_3['CpG'].values
}

tissues = tissues_df['Tissue'].unique() # Get a list of all tissues
tissue_datasets = pd.DataFrame(columns=['Tissue', 'Clock', 'Dataset']) # create a dataframe to store the datasets

# List of tissues not included
tissues_not_included = []

# fill the dictionary with dataset and respective tissue name
for tissue in tissues:
    if metadata[metadata['Tissue'] == tissue].shape[0] < 10:
        tissues_not_included.append(tissue)
    else:
        for clock_name, clock_cpgs in clocks.items():
            tissue_df = globals()['{}_methylation_dataset'.format(tissue)].copy()
            tissue_df = tissue_df[tissue_df['CpG'].isin(clock_cpgs)]
            tissue_datasets.loc[len(tissue_datasets)] = [tissue, clock_name, tissue_df]

            # Define a variable for each of the datasets dynamically
            variable_name = f'{tissue.lower()}_{clock_name}_dataset'
            globals()[variable_name] = tissue_df

print('Tissues not included:', tissues_not_included)
print('Total number of tissues not included:', len(tissues_not_included))
tissue_datasets.head()

# Note to self: to access any of he tissue-specific datasets, use the variable name in the format: {tissue}_{clock}_dataset (cortex_clock1_dataset)
# Out:
# Tissues not included: ['Testis', 'Pancreas', 'Thyroid', 'Blubber', 'Ileum', 'Duodenum', 'Tendon', 'Mammary', 'TemporalCortex', 'Lamina', 'OccipitalCortex', 'ParietalCortex', 'MitralValve', 'AdrenalCortex', 'Sacrocaudalis', 'Cecum', 'Uterus', 'Jejunum', 'Larynx', 'SpinalCord', 'Suspensory', 'Cartilage', 'Astrocyte', 'Epidermis', 'Dermis', 'Maybe.Larynx']
# Total number of tissues not included: 26
#    Tissue   Clock                                            Dataset
# 0  Cortex  clock1                CpG  202794570001_R01C01  202794...
# 1  Cortex  clock2                CpG  202794570001_R01C01  202794...
# 2  Cortex  clock3                CpG  202794570001_R01C01  202794...
# 3   Liver  clock1                CpG  202794570002_R01C01  202794...
# 4   Liver  clock2                CpG  202794570002_R01C01  202794...

# %%
cortex_clock2_dataset.head()
# Out:
#             CpG  202794570001_R01C01  202794570001_R01C02  \
# 29   cg00020468             0.946976             0.932568
# 141  cg00096922             0.056694             0.044397
# 142  cg00098422             0.927504             0.918589
# 156  cg00106940             0.007289             0.006400
# 279  cg00195533             0.431196             0.496208
#
#      202794570001_R02C01  202794570001_R02C02  202794570001_R03C01  \
# 29              0.940156             0.931719             0.946127
# 141             0.051426             0.055706             0.053108
# 142             0.922592             0.934535             0.940001
# 156             0.007009             0.006729             0.007864
# 279             0.448819             0.459928             0.447120
#
#      202794570001_R03C02  202794570001_R04C01  202794570001_R04C02  \
# 29              0.938136             0.939809             0.936536
# 141             0.045419             0.053473             0.058857
# ...

# %% [markdown]
# ## 1. Data Analysis

# %%
### Function to analyze methylation patterns

def analyze_methylation_patterns(tissue_datasets, clock_name, output_folder):
    ''' This function analyzes methylation patterns for a given clock across different tissues.

    Args:
    - tissue_datasets: a dataframe containing tissue-specific datasets for each clock
    - clock_name: the name of the clock to analyze
    - output_folder: the folder to save the results

    Raises:
    - An error if an exception occurs during the analysis
    
    Returns:
    - A dictionary containing the following results:
        - high_methylation: CpGs with mean methylation > 0.8 across tissues
        - low_methylation: CpGs with mean methylation < 0.2 across tissues
        - variable_cpgs: CpGs with methylation range > 0.1 across tissues
        - mean_methylation: mean methylation values for each CpG across tissues

    '''

    try:
        # Create output folder if it doesn't exist
        os.makedirs(output_folder, exist_ok=True)
        
        # Filter datasets for the specific clock
        clock_data = tissue_datasets[tissue_datasets['Clock'] == clock_name]
        
        # Create a dictionary to store summary statistics for each tissue
        summary_stats = {}
        
        for _, row in clock_data.iterrows():
            tissue = row['Tissue']
            dataset = row['Dataset']
            
            # Ensure 'CpG' is the index and samples are columns
            if dataset.index.name != 'CpG':
                dataset = dataset.set_index('CpG')
            
            # Calculate summary statistics
            summary = dataset.agg(['mean', 'median', 'std', lambda x: x.max() - x.min()], axis=1)
            summary.columns = ['mean', 'median', 'std', 'range']
            summary_stats[tissue] = summary
        
        # Combine summary statistics into a single dataframe
        combined_stats = pd.concat(summary_stats, axis=1)
        
        # Save combined stats
        combined_stats.to_csv(os.path.join(output_folder, f'{clock_name}_combined_stats.csv'))
        
        # Calculate and save mean methylation
        mean_methylation = pd.DataFrame({tissue: data['mean'] for tissue, data in summary_stats.items()})
        mean_methylation.to_csv(os.path.join(output_folder, f'{clock_name}_mean_methylation.csv'))
        
        # Identify consistent patterns
        mean_methylation_across_tissues = mean_methylation.mean(axis=1)
        
        high_methylation = mean_methylation_across_tissues[mean_methylation_across_tissues > 0.8]
        low_methylation = mean_methylation_across_tissues[mean_methylation_across_tissues < 0.2]
        
        # More stringent: 5th to 95th percentile with a higher threshold
        methylation_range = mean_methylation.quantile(0.90, axis=1) - mean_methylation.quantile(0.1, axis=1)
        variable_cpgs = methylation_range[methylation_range > 0.1]
        
        # Save consistent patterns
        pd.Series({'high_methylation': len(high_methylation),
                   'low_methylation': len(low_methylation),
                   'variable_cpgs': len(variable_cpgs)}).to_csv(os.path.join(output_folder, f'{clock_name}_consistent_patterns.csv'))
        
        # Statistical test (ANOVA)
        def anova_test(cpg):
            try:
                groups = [tissue_data.loc[cpg] for tissue_data in summary_stats.values() if cpg in tissue_data.index]
                if len(groups) > 1:
                    f_value, p_value = stats.f_oneway(*groups)
                    return p_value
                else:
                    print(f"Not enough data for ANOVA for CpG: {cpg}")
                    return np.nan
            except KeyError:
                print(f"KeyError: '{cpg}' not found in one of the tissue datasets.")
                return np.nan
        
        # Use CpG names from the index of mean_methylation
        cpg_names = mean_methylation.index
        anova_results = pd.Series({cpg: anova_test(cpg) for cpg in cpg_names})
        significant_cpgs = anova_results[anova_results < 0.01]
        
        # Save ANOVA results
        anova_results.to_csv(os.path.join(output_folder, f'{clock_name}_anova_results.csv'))
        significant_cpgs.to_csv(os.path.join(output_folder, f'{clock_name}_significant_cpgs.csv'))
        
        print(f"Analysis for {clock_name} complete. Results saved in {output_folder}")

        return {
            'high_methylation': high_methylation,
            'low_methylation': low_methylation,
            'variable_cpgs': variable_cpgs,
            'mean_methylation': mean_methylation
        }
    
    except Exception as e:
        print(f"An error occurred during analysis of {clock_name}: {str(e)}")
        return None

# %%
# Perform analysis for each clock and store results

# Perform analysis for each clock and store results
output_base_folder = 'Cross-Tissue Methylation Patterns'
os.makedirs(output_base_folder, exist_ok=True)

analysis_results = {}

for clock_name in clocks.keys():
    print(f"\nAnalyzing {clock_name}...")
    output_folder = os.path.join(output_base_folder, clock_name)
    result = analyze_methylation_patterns(tissue_datasets, clock_name, output_folder)
    if result is not None:
        analysis_results[clock_name] = result
    else:
        print(f"Analysis failed for {clock_name}")

print('\nAnalysis Complete')

# # Perform analysis for each clock

# # List of clocks with their respective CpGs
# # clocks = {
# #     'clock1': clock1['CpG'].values,
# #     'clock2': clock2['CpG'].values,
# #     'clock3': clock3['CpG'].values,
# #     'clock2_3': clock2_3['CpG'].values
# # }

# output_base_folder = 'Cross-Tissue Methylation Patterns'
# os.makedirs(output_base_folder, exist_ok=True)

# for clock_name in clocks.keys():
#     print(f"\nAnalyzing {clock_name}...")
#     output_folder = os.path.join(output_base_folder, clock_name)
#     analyze_methylation_patterns(tissue_datasets, clock_name, output_folder)

# print('\nAnalysis Complete')
# Out:
# Analyzing clock1...
# Analysis for clock1 complete. Results saved in Cross-Tissue Methylation Patterns\clock1
#
# Analyzing clock2...
# Analysis for clock2 complete. Results saved in Cross-Tissue Methylation Patterns\clock2
#
# Analyzing clock3...
# Analysis for clock3 complete. Results saved in Cross-Tissue Methylation Patterns\clock3
#
# Analysis Complete

# %%
analysis_results.keys()
# Out:
# dict_keys(['clock1', 'clock2', 'clock3'])

# %%
### Function to create visualizations 

def create_visualizations(clock_name, output_folder):
    # Load data
    mean_methylation = pd.read_csv(os.path.join(output_folder, f'{clock_name}_mean_methylation.csv'), index_col=0)
    
    # Transpose mean_methylation to have tissues on x-axis and CpGs on y-axis
    mean_methylation_transposed = mean_methylation.transpose()



    ##### HEATMAP #####
    
    # Heatmap of mean methylation levels
    plt.figure(figsize=(20, 10))
    sns.heatmap(mean_methylation_transposed, cmap='coolwarm', center=0.5)
    plt.title(f'Mean Methylation Levels Across Tissues - {clock_name}',
              fontsize=15,
              fontweight='bold',
              pad=20)
    plt.xticks(rotation=90)
    plt.ylabel('Tissue')
    # plt.colorbar(label='Mean Methylation Level')
    plt.savefig(os.path.join(output_folder, f'{clock_name}_heatmap.png'), dpi=300, bbox_inches='tight')
    plt.close()



    ##### CLUSTERMAP #####

    # Heatmaps of mean methylation levels for each tissue with clustermap
    plt.figure(figsize=(20, 10))
    clustergrid = sns.clustermap(mean_methylation_transposed, 
                   cmap='coolwarm', center=0.5, 
                   cbar_pos=(.75, .61, .03, .20), #[left, bottom, width, height]
                   vmin=0, vmax=1,
                   cbar_kws={'label': 'Mean Methylation Level'},
                   yticklabels=True
                   )
    plt.title(f'Mean Methylation Levels Across Tissues (Clustermap) - {clock_name.capitalize()}',
              fontsize=15,
              fontweight='bold', 
              loc='right',
              pad=20)
    clustergrid.ax_row_dendrogram.set_visible(False)
    clustergrid.ax_col_dendrogram.set_visible(False)

    # Move y-axis labels to the left
    plt.setp(clustergrid.ax_heatmap.yaxis.get_majorticklabels(), rotation=0)
    clustergrid.ax_heatmap.yaxis.tick_left()
    
    plt.savefig(os.path.join(output_folder, f'{clock_name}_clustermap.png'), dpi=300, bbox_inches='tight')
    plt.close()
    


    ##### BOXPLOT #####

    # Box plot of mean methylation levels
    plt.figure(figsize=(20, 10))
    sns.boxplot(data=mean_methylation, orient='h', palette='viridis')
    plt.title(f'Distribution of Mean Methylation Levels Across Tissues - {clock_name}',
              fontsize=15,
              fontweight='bold',
              pad=20)
    plt.xlabel('Mean Methylation Level')
    plt.ylabel('Tissue')
    plt.savefig(os.path.join(output_folder, f'{clock_name}_boxplot.png'), dpi=300, bbox_inches='tight')
    plt.close()



    ##### CORRELATION MATRIX #####

    # Correlation analysis (using the original mean_methylation dataframe)
    correlation_matrix = mean_methylation.corr()
    plt.figure(figsize=(12, 10))
    sns.heatmap(correlation_matrix, annot=False, cmap='coolwarm')
    plt.title(f'Correlation of Methylation Patterns Between Tissues - {clock_name}',
              fontsize=15,
              fontweight='bold',
              pad=20)
    plt.savefig(os.path.join(output_folder, f'{clock_name}_correlation.png'), dpi=300, bbox_inches='tight')
    plt.close()
    
    print(f"Visualizations for {clock_name} complete. Saved in {output_folder}")

# %%
### Create Visualizations

output_base_folder = 'Cross-Tissue Methylation Patterns'

# Loop just the fisrt 2 clocks
for clock_name in clocks.keys():
# for clock_name in clocks.keys():

    print(f"\nCreating visualizations for {clock_name}...")

    output_folder = os.path.join(output_base_folder, clock_name)
    
    create_visualizations(clock_name, output_folder)

    print(f"\nVisualizations for {clock_name} complete. Saved in {output_folder}")
# Out:
# Creating visualizations for clock1...
# Visualizations for clock1 complete. Saved in Cross-Tissue Methylation Patterns\clock1
#
# Visualizations for clock1 complete. Saved in Cross-Tissue Methylation Patterns\clock1
#
# Creating visualizations for clock2...
# Visualizations for clock2 complete. Saved in Cross-Tissue Methylation Patterns\clock2
#
# Visualizations for clock2 complete. Saved in Cross-Tissue Methylation Patterns\clock2
#
# Creating visualizations for clock3...
# Visualizations for clock3 complete. Saved in Cross-Tissue Methylation Patterns\clock3
#
# Visualizations for clock3 complete. Saved in Cross-Tissue Methylation Patterns\clock3
#
# Creating visualizations for clock2_3...
# Visualizations for clock2_3 complete. Saved in Cross-Tissue Methylation Patterns\clock2_3
#
# Visualizations for clock2_3 complete. Saved in Cross-Tissue Methylation Patterns\clock2_3

# %% [markdown]
# ## 2. Results

# %% [markdown]
# ### 2.1. Summary

# %%
### Summary of CpGs with consistent methylation patterns

# Dictionaries to store results
high_methylation_cpgs = {}
low_methylation_cpgs = {}
variable_methylation_cpgs = {}

# Summary of CpGs with consistent methylation patterns
for clock_name, results in analysis_results.items():

    high_methylation = results['high_methylation'] # CpGs with high methylation
    low_methylation = results['low_methylation'] # CpGs with low methylation
    variable_cpgs = results['variable_cpgs'] # CpGs with variable methylation
    mean_methylation = results['mean_methylation'] # Mean methylation levels across tissues

    # Store the CpG indices and mean methylation values
    high_methylation_cpgs[clock_name] = pd.DataFrame({
        'CpG': high_methylation.index, # CpG names
        'Mean Methylation': high_methylation.values # Mean methylation values
    })

    low_methylation_cpgs[clock_name] = pd.DataFrame({
        'CpG': low_methylation.index,
        'Mean Methylation': low_methylation.values
    })

    variable_methylation_cpgs[clock_name] = pd.DataFrame({
        'CpG': variable_cpgs.index,
        'Mean Methylation': mean_methylation.mean(axis=1)[variable_cpgs.index].values # Mean methylation values for variable CpGs only
    })

    # Print results
    print(f"\n{clock_name.upper()}")
    print(f"Number of CpGs consistently high methylated across tissues in {clock_name}: {len(high_methylation_cpgs[clock_name])}")
    print(f"Number of CpGs consistently low methylated across tissues in {clock_name}: {len(low_methylation_cpgs[clock_name])}")
    print(f"Number of CpGs with high variable methylation across tissues in {clock_name}: {len(variable_methylation_cpgs[clock_name])}")
    print(f'Number of CpGs overlapped between high and variable methylation: {len(set(high_methylation_cpgs[clock_name]['CpG']).intersection(set(variable_methylation_cpgs[clock_name]['CpG'])))}')
    print(f'Number of CpGs overlapped between low and variable methylation: {len(set(low_methylation_cpgs[clock_name]['CpG']).intersection(set(variable_methylation_cpgs[clock_name]['CpG'])))}')
    print(f'Number of CpGs with high variable methylation that are not overlapped with high or low methylation: {len(set(variable_methylation_cpgs[clock_name]['CpG']) - set(high_methylation_cpgs[clock_name]['CpG']) - set(low_methylation_cpgs[clock_name]['CpG']))}')
# Out:
# CLOCK1
# Number of CpGs consistently high methylated across tissues in clock1: 68
# Number of CpGs consistently low methylated across tissues in clock1: 94
# Number of CpGs with high variable methylation across tissues in clock1: 244
# Number of CpGs overlapped between high and variable methylation: 48
# Number of CpGs overlapped between low and variable methylation: 42
# Number of CpGs with high variable methylation that are not overlapped with high or low methylation: 154
#
# CLOCK2
# Number of CpGs consistently high methylated across tissues in clock2: 238
# Number of CpGs consistently low methylated across tissues in clock2: 257
# Number of CpGs with high variable methylation across tissues in clock2: 561
# Number of CpGs overlapped between high and variable methylation: 154
# Number of CpGs overlapped between low and variable methylation: 101
# Number of CpGs with high variable methylation that are not overlapped with high or low methylation: 306
#
# CLOCK3
# ...

# %%
### Bar plot of the number of CpGs with consistent methylation patterns (Without overlapping CpGs)

# Data for the bar plot
clocks = list(analysis_results.keys())

high_methylation = [len(results['high_methylation']) for results in analysis_results.values()]
low_methylation = [len(results['low_methylation']) for results in analysis_results.values()]
variable_methylation = [len(results['variable_cpgs']) for results in analysis_results.values()]

x = range(len(clocks))

fig, ax = plt.subplots(figsize=(7, 7))

bar_width = 0.25

# Apply the viridis colormap
viridis = colormaps.get_cmap('viridis')
# colors = [viridis(i / 2) for i in range(3)]  # Generate 3 distinct colors from the colormap
# Select specific viridis colors
colors = [viridis(0.0), viridis(0.3), viridis(0.6)]

# Plot the bars with viridis colors
ax.bar(x, high_methylation, width=bar_width, label='High', color=colors[0], alpha=0.7)
ax.bar([p + bar_width for p in x], low_methylation, width=bar_width, label='Low', color=colors[1], alpha=0.7)
ax.bar([p + 2 * bar_width for p in x], variable_methylation, width=bar_width, label='Variable', color=colors[2], alpha=0.7)

# Set the labels and title
ax.set_xlabel('Clocks', fontsize=12)
ax.set_ylabel('Number of CpGs', fontsize=12)
ax.set_title('CpGs Patterns Across Clocks', fontsize=14)
ax.set_xticks([p + bar_width for p in x])
ax.set_xticklabels(clocks, rotation=45, ha='right')
ax.legend(fontsize=10)

# Add value labels on top of each bar
for i, v in enumerate(high_methylation):
    ax.text(i, v, str(v), ha='center', va='bottom')
for i, v in enumerate(low_methylation):
    ax.text(i + bar_width, v, str(v), ha='center', va='bottom')
for i, v in enumerate(variable_methylation):
    ax.text(i + 2 * bar_width, v, str(v), ha='center', va='bottom')

# Add a legend with a title
ax.legend(title='Methylation', fontsize=10, title_fontsize='11', loc='upper right')

# Adjust layout and display the plot
plt.tight_layout()
plt.show()

# %%
### Bar plot of the number of CpGs with consistent methylation patterns (With overlapping CpGs)

# Calculate overlaps
overlap_high_variable = [len(results['high_methylation'].index.intersection(results['variable_cpgs'].index)) for results in analysis_results.values()]
overlap_low_variable = [len(results['low_methylation'].index.intersection(results['variable_cpgs'].index)) for results in analysis_results.values()]

# Create stacked values for variable bars
stacked_high = [min(high, var) for high, var in zip(overlap_high_variable, variable_methylation)]
stacked_low = [min(low, var) for low, var in zip(overlap_low_variable, variable_methylation)]
stacked_variable = [var - high - low for var, high, low in zip(variable_methylation, stacked_high, stacked_low)]

x = range(len(clocks))

fig, ax = plt.subplots(figsize=(7, 7))

bar_width = 0.25

# Apply the viridis colormap
viridis = colormaps.get_cmap('viridis')
colors = [viridis(0.0), viridis(0.3), viridis(0.6), viridis(0.7), viridis(0.8)]  # Generate 3 distinct colors from the colormap}

# Plot the bars with viridis colors
ax.bar(x, high_methylation, width=bar_width, label='Hyper', color=colors[0], alpha=0.7)
ax.bar([p + bar_width for p in x], low_methylation, width=bar_width, label='Hypo', color=colors[1], alpha=0.7)

# Plot stacked bars for variable methylation
ax.bar([p + 2 * bar_width for p in x], stacked_variable, width=bar_width, bottom=np.array(stacked_high) + np.array(stacked_low), label='Variable Only', color=colors[4], alpha=0.7)
ax.bar([p + 2 * bar_width for p in x], stacked_low, width=bar_width, bottom=stacked_high, label='Hypo in Variable', color=colors[3], alpha=0.7)
ax.bar([p + 2 * bar_width for p in x], stacked_high, width=bar_width, label='Hyper in Variable', color=colors[2], alpha=0.7)




# Set the labels and title
ax.set_xlabel('Clocks', fontsize=12)
ax.set_ylabel('Number of CpGs', fontsize=12)
ax.set_title('CpGs Patterns Across Clocks', fontsize=14)
ax.set_xticks([p + bar_width for p in x])
ax.set_xticklabels(clocks, rotation=45, ha='right')

# Add a legend with a title
ax.legend(title='Methylation', fontsize=10, title_fontsize='11', loc='upper left')

# Add value labels on top of each bar
for i, v in enumerate(high_methylation):
    ax.text(i, v, str(v), ha='center', va='bottom')
for i, v in enumerate(low_methylation):
    ax.text(i + bar_width, v, str(v), ha='center', va='bottom')
for i, (high, low, variable) in enumerate(zip(stacked_high, stacked_low, stacked_variable)):
    total_height = high + low + variable
    ax.text(i + 2 * bar_width, high / 2, str(high), ha='center', va='center', color='black')
    ax.text(i + 2 * bar_width, high + low / 2, str(low), ha='center', va='center', color='black')
    ax.text(i + 2 * bar_width, high + low + variable / 2, str(variable), ha='center', va='center', color='black')
    ax.text(i + 2 * bar_width, total_height, str(total_height), ha='center', va='bottom', color='black')

# Adjust layout and display the plot
plt.tight_layout()
plt.show()

# %%
### Venn diagram of number of CpGs present in All clocks

from matplotlib_venn import venn3
import matplotlib.pyplot as plt
from matplotlib.colors import to_rgb
import numpy as np

# Your existing code to get the intersections
high_methylated_sets = {clock: set(df['CpG']) for clock, df in high_methylation_cpgs.items()}
low_methylated_sets = {clock: set(df['CpG']) for clock, df in low_methylation_cpgs.items()}
variable_methylated_sets = {clock: set(df['CpG']) for clock, df in variable_methylation_cpgs.items()}

# Convert the CpGs to strings and find intersections
clock1 = set(str(cpg) for cpg in high_methylated_sets['clock1'])
clock2 = set(str(cpg) for cpg in high_methylated_sets['clock2'])
clock3 = set(str(cpg) for cpg in high_methylated_sets['clock3'])

all_clocks_high_methylated_cpgs = set.intersection(clock1, clock2, clock3)
all_clocks_low_methylated_cpgs = set.intersection(
    set(str(cpg) for cpg in low_methylated_sets['clock1']),
    set(str(cpg) for cpg in low_methylated_sets['clock2']),
    set(str(cpg) for cpg in low_methylated_sets['clock3'])
)
all_clocks_variable_methylated_cpgs = set.intersection(
    set(str(cpg) for cpg in variable_methylated_sets['clock1']),
    set(str(cpg) for cpg in variable_methylated_sets['clock2']),
    set(str(cpg) for cpg in variable_methylated_sets['clock3'])
)

# Create a Venn diagram with Viridis colors
plt.figure(figsize=(10, 10))

# Format the set labels with the total number
set_labels = [
    f'High Methylation ({len(all_clocks_high_methylated_cpgs)})',
    f'Low Methylation ({len(all_clocks_low_methylated_cpgs)})',
    f'Variable Methylation ({len(all_clocks_variable_methylated_cpgs)})'
]

# Create the Venn diagram
v = venn3([all_clocks_high_methylated_cpgs, all_clocks_low_methylated_cpgs, all_clocks_variable_methylated_cpgs],
          set_labels=set_labels)

# Generate 7 colors from the colormap
colors = [plt.cm.viridis(i / 7) for i in range(6)]

# Set colors for the Venn diagram areas
for i, patch in enumerate(v.patches):
    if patch is not None:
        patch.set_color(colors[i])
        patch.set_edgecolor('black')  # Optionally add a border for better visualization

plt.title('CpGs Consistently Methylated Across All Clocks', fontsize=16)

plt.show()


# Print the totals
print(f"CpGs consistently high methylated across all clocks: {len(all_clocks_high_methylated_cpgs)}")
print(f"CpGs consistently low methylated across all clocks: {len(all_clocks_low_methylated_cpgs)}")
print(f"CpGs consistently variable methylated across all clocks: {len(all_clocks_variable_methylated_cpgs)}")
# Out:
# CpGs consistently high methylated across all clocks: 17
# CpGs consistently low methylated across all clocks: 42
# CpGs consistently variable methylated across all clocks: 81

# %%
### Plot of number of CpGs present in All clocks

# Your existing code to calculate counts
counts = {
    'Hypermethylation': len(all_clocks_high_methylated_cpgs),
    'Hypomethylation': len(all_clocks_low_methylated_cpgs),
    'Variable Methylation': len(all_clocks_variable_methylated_cpgs)
}

# Create a DataFrame for easier plotting
df = pd.DataFrame(list(counts.items()), columns=['Category', 'Count'])

# Create the plot
fig, ax = plt.subplots(figsize=(6, 6))

# Viridis colormap
colors = [viridis(0.0), viridis(0.3), viridis(0.6), viridis(0.7), viridis(0.8)]

# Plot horizontal bars
bars = ax.barh(df['Category'], df['Count'], color=colors, alpha=0.7)

# Customize the plot
ax.set_title('CpGs Consistently Methylated Across All Clocks and Tissues', fontsize=16, pad=20)
ax.set_xlabel('Number of CpGs', fontsize=12)
ax.set_ylabel('')

# Remove top and right spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Add value labels on the bars
for i, (v, category) in enumerate(zip(df['Count'], df['Category'])):
    ax.text(v + 0.5, i, str(v), va='center', fontweight='bold')

# Add a light grid
ax.grid(axis='x', linestyle='--', alpha=0.7)

# Adjust layout and display
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 2.2. High Methylation CpGs in All Tissues

# %%
### CpGs that are high methylated in all clocks

# Get the set of high methylated CpGs for each clock
high_methylated_sets = {clock: set(df['CpG']) for clock, df in high_methylation_cpgs.items()}

# Convert the CpGs to strings to avoid hash errors and exclude clock2_3 
clock1 = set(str(cpg) for cpg in high_methylated_sets['clock1'])
clock2 = set(str(cpg) for cpg in high_methylated_sets['clock2'])
clock3 = set(str(cpg) for cpg in high_methylated_sets['clock3'])
# clock2_3 = set(str(cpg) for cpg in high_methylated_sets['clock2_3']) # Not used at it already is an overlap of two clocks

# Find the intersection of all sets
all_clocks_high_methylated_cpgs = set.intersection(clock1, clock2, clock3) #instead of set.intersection(*high_methylated_sets.values()) as this pulls all the clocks and I dont want to include clock2_3

# Convert the result to a list if needed
all_clocks_high_methylated_cpgs = list(all_clocks_high_methylated_cpgs)

# Set the output folder
output_folder = 'Cross-Tissue Methylation Patterns'
os.makedirs(output_folder, exist_ok=True)

# save the list to a csv file
all_clocks_high_methylated_cpgs_df = pd.DataFrame(all_clocks_high_methylated_cpgs, columns=['CpG'])
all_clocks_high_methylated_cpgs_df.to_csv(os.path.join(output_folder, 'all_clocks_high_methylated_cpgs.csv'), index=False)

# Print the result
print(f"\nNumber of CpGs consistently high methylated across all clocks: {len(all_clocks_high_methylated_cpgs)}")
print("CpGs consistently high methylated across all clocks:")
print(all_clocks_high_methylated_cpgs)
# Out:
# Number of CpGs consistently high methylated across all clocks: 17
# CpGs consistently high methylated across all clocks:
# ['cg23778391', 'cg17718834', 'cg12382554', 'cg05401971', 'cg06679868', 'cg12449245', 'cg17357006', 'cg17114460', 'cg27547112', 'cg21907062', 'cg14443903', 'cg19195912', 'cg15340018', 'cg03820088', 'cg17516812', 'cg06004718', 'cg14701342']

# %%
### Venn diagram of high methylated CpGs across clocks

# Select the CpGs that are high methylated in each clock
venn = venn3([high_methylated_sets['clock1'], high_methylated_sets['clock2'], high_methylated_sets['clock3']],
      ('Clock1', 'Clock2', 'Clock3'))

# Apply the viridis colormap
viridis = colormaps.get_cmap('viridis')  # Get the viridis colormap

# Generate 7 colors from the colormap
colors = [viridis(i / 6) for i in range(7)]

# Set colors for the Venn diagram areas
for i, patch in enumerate(venn.patches):
    if patch is not None:
        patch.set_color(colors[i])
        patch.set_edgecolor('black')  # Optionally add a border for better visualization
        
plt.title('Hypermethylated CpGs')
plt.show()

# %%
# Summary of Hypermethylated CpGs
print(f'Number of Hypermethylated CpGs in Clock 1: {len(high_methylated_sets["clock1"])}')
print(f'Number of Hypermethylated CpGs of Clock 1 that Overlap with Clock 2: {len(high_methylated_sets["clock1"].intersection(high_methylated_sets["clock2"]))}')
print(f'Number of Hypermethylated CpGs of Clock 1 that Overlap with Clock 3: {len(high_methylated_sets["clock1"].intersection(high_methylated_sets["clock3"]))}')

print(f'\nNumber of Hypermethylated CpGs in Clock 2: {len(high_methylated_sets["clock2"])}')
print(f'Number of Hypermethylated CpGs of Clock 2 that Overlap with Clock 1: {len(high_methylated_sets["clock2"].intersection(high_methylated_sets["clock1"]))}')
print(f'Number of Hypermethylated CpGs of Clock 2 that Overlap with Clock 3: {len(high_methylated_sets["clock2"].intersection(high_methylated_sets["clock3"]))}')

print(f'\nNumber of Hypermethylated CpGs in Clock 3: {len(high_methylated_sets["clock3"])}')
print(f'Number of Hypermethylated CpGs of Clock 3 that Overlap with Clock 1: {len(high_methylated_sets["clock3"].intersection(high_methylated_sets["clock1"]))}')
print(f'Number of Hypermethylated CpGs of Clock 3 that Overlap with Clock 2: {len(high_methylated_sets["clock3"].intersection(high_methylated_sets["clock2"]))}')
# Out:
# Number of Hypermethylated CpGs in Clock 1: 68
# Number of Hypermethylated CpGs of Clock 1 that Overlap with Clock 2: 25
# Number of Hypermethylated CpGs of Clock 1 that Overlap with Clock 3: 23
#
# Number of Hypermethylated CpGs in Clock 2: 238
# Number of Hypermethylated CpGs of Clock 2 that Overlap with Clock 1: 25
# Number of Hypermethylated CpGs of Clock 2 that Overlap with Clock 3: 121
#
# Number of Hypermethylated CpGs in Clock 3: 216
# Number of Hypermethylated CpGs of Clock 3 that Overlap with Clock 1: 23
# Number of Hypermethylated CpGs of Clock 3 that Overlap with Clock 2: 121

# %% [markdown]
# ### 2.3. Low Methylation CpGs in All Tissues

# %%
### CpG that are low methylated in all clocks

# Get the set of low methylated CpGs for each clock
low_methylated_sets = {clock: set(df['CpG']) for clock, df in low_methylation_cpgs.items()}

# Convert the CpGs to strings to avoid hash errors and exclude clock2_3
clock1 = set(str(cpg) for cpg in low_methylated_sets['clock1'])
clock2 = set(str(cpg) for cpg in low_methylated_sets['clock2'])
clock3 = set(str(cpg) for cpg in low_methylated_sets['clock3'])
# clock2_3 = set(str(cpg) for cpg in low_methylated_sets['clock2_3']) # Not used at it already is an overlap of two clocks

# Find the intersection of all sets
all_clocks_low_methylated_cpgs = set.intersection(clock1, clock2, clock3) #instead of set.intersection(*low_methylated_sets.values()) as this pulls all the clocks and I dont want to include clock2_3

# Convert the result to a list if needed
all_clocks_low_methylated_cpgs = list(all_clocks_low_methylated_cpgs)

# Set the output folder
output_folder = 'Cross-Tissue Methylation Patterns'
os.makedirs(output_folder, exist_ok=True)

# save the list to a csv file
all_clocks_low_methylated_cpgs_df = pd.DataFrame(all_clocks_low_methylated_cpgs, columns=['CpG'])
all_clocks_low_methylated_cpgs_df.to_csv(os.path.join(output_folder, 'all_clocks_low_methylated_cpgs.csv'), index=False)

# Print the result
print(f"\nNumber of CpGs consistently low methylated across all clocks: {len(all_clocks_low_methylated_cpgs)}")
print("CpGs consistently low methylated across all clocks:")
print(all_clocks_low_methylated_cpgs)
# Out:
# Number of CpGs consistently low methylated across all clocks: 42
# CpGs consistently low methylated across all clocks:
# ['cg02692845', 'cg13058338', 'cg26844246', 'cg27201382', 'cg08074329', 'cg08938156', 'cg02532525', 'cg24504442', 'cg09710440', 'cg05575054', 'cg14919591', 'cg01019040', 'cg11235379', 'cg18502834', 'cg04998737', 'cg04368876', 'cg27228973', 'cg13188467', 'cg18918349', 'cg26512254', 'cg14361875', 'cg19090691', 'cg24352905', 'cg04706544', 'cg08446005', 'cg22338839', 'cg11516694', 'cg00694357', 'cg13242392', 'cg01153166', 'cg06736685', 'cg20804050', 'cg22354333', 'cg23415880', 'cg23985931', 'cg12841266', 'cg19981759', 'cg18223258', 'cg23087015', 'cg15809488', 'cg12651099', 'cg07875786']

# %%
### Venn diagram of low methylated CpGs across clocks
 
# Select the CpGs that are low methylated in each clock
venn = venn3([low_methylated_sets['clock1'], low_methylated_sets['clock2'], low_methylated_sets['clock3']],
      ('Clock1', 'Clock2', 'Clock3'))

# Apply the viridis colormap
viridis = colormaps.get_cmap('viridis')  # Get the viridis colormap

# Generate 7 colors from the colormap
colors = [viridis(i / 6) for i in range(7)]

# Set colors for the Venn diagram areas
for i, patch in enumerate(venn.patches):
    if patch is not None:
        patch.set_color(colors[i])
        patch.set_edgecolor('black')  # Optionally add a border for better visualization
        
plt.title('Hypomethylated CpGs')
plt.show()

# %%
# Summary of Hypomethylated CpGs
print(f'Number of Hypomethylated CpGs in Clock 1: {len(low_methylated_sets["clock1"])}')
print(f'Number of Hypomethylated CpGs of Clock 1 that Overlap with Clock 2: {len(low_methylated_sets["clock1"].intersection(low_methylated_sets["clock2"]))}')
print(f'Number of Hypomethylated CpGs of Clock 1 that Overlap with Clock 3: {len(low_methylated_sets["clock1"].intersection(low_methylated_sets["clock3"]))}')

print(f'\nNumber of Hypomethylated CpGs in Clock 2: {len(low_methylated_sets["clock2"])}')
print(f'Number of Hypomethylated CpGs of Clock 2 that Overlap with Clock 1: {len(low_methylated_sets["clock2"].intersection(low_methylated_sets["clock1"]))}')
print(f'Number of Hypomethylated CpGs of Clock 2 that Overlap with Clock 3: {len(low_methylated_sets["clock2"].intersection(low_methylated_sets["clock3"]))}')

print(f'\nNumber of Hypomethylated CpGs in Clock 3: {len(low_methylated_sets["clock3"])}')
print(f'Number of Hypomethylated CpGs of Clock 3 that Overlap with Clock 1: {len(low_methylated_sets["clock3"].intersection(low_methylated_sets["clock1"]))}')
print(f'Number of Hypomethylated CpGs of Clock 3 that Overlap with Clock 2: {len(low_methylated_sets["clock3"].intersection(low_methylated_sets["clock2"]))}')
# Out:
# Number of Hypomethylated CpGs in Clock 1: 94
# Number of Hypomethylated CpGs of Clock 1 that Overlap with Clock 2: 61
# Number of Hypomethylated CpGs of Clock 1 that Overlap with Clock 3: 50
#
# Number of Hypomethylated CpGs in Clock 2: 257
# Number of Hypomethylated CpGs of Clock 2 that Overlap with Clock 1: 61
# Number of Hypomethylated CpGs of Clock 2 that Overlap with Clock 3: 138
#
# Number of Hypomethylated CpGs in Clock 3: 241
# Number of Hypomethylated CpGs of Clock 3 that Overlap with Clock 1: 50
# Number of Hypomethylated CpGs of Clock 3 that Overlap with Clock 2: 138

# %% [markdown]
# ### 2.4. Variable Methylation CpGs in All Tissues

# %%
# ### Overlapping CpGs in High Methylation and Variable Methylation

# # Get the set of CpGs with variable methylation for each clock
# variable_methylated_sets = {clock: set(df['CpG']) for clock, df in variable_methylation_cpgs.items()}
# clock1 = set(str(cpg) for cpg in variable_methylated_sets['clock1'])
# clock2 = set(str(cpg) for cpg in variable_methylated_sets['clock2'])
# clock3 = set(str(cpg) for cpg in variable_methylated_sets['clock3'])

# # Find the intersection of all sets
# all_clocks_variable_methylated_cpgs = set.intersection(clock1, clock2, clock3)

# %%
### CpGs with high variable methylation in all clocks (with and without Overlaps between high and variable methylation)

# Get the set of CpGs with high variable methylation for each clock
variable_methylated_sets = {clock: set(df['CpG']) for clock, df in variable_methylation_cpgs.items()}

# Convert the CpGs to strings to avoid hash errors and exclude clock2_3
clock1 = set(str(cpg) for cpg in variable_methylated_sets['clock1'])
clock2 = set(str(cpg) for cpg in variable_methylated_sets['clock2'])
clock3 = set(str(cpg) for cpg in variable_methylated_sets['clock3'])

# Find the intersection of all sets (CpGs that are variable across all clocks)
all_clocks_variable_methylated_cpgs = set.intersection(clock1, clock2, clock3)

# Identify high and low methylated CpGs across all clocks
high_methylated_cpgs = set(str(cpg) for cpg in set.intersection(
    set(high_methylation_cpgs['clock1']['CpG']),
    set(high_methylation_cpgs['clock2']['CpG']),
    set(high_methylation_cpgs['clock3']['CpG'])
))

low_methylated_cpgs = set(str(cpg) for cpg in set.intersection(
    set(low_methylation_cpgs['clock1']['CpG']),
    set(low_methylation_cpgs['clock2']['CpG']),
    set(low_methylation_cpgs['clock3']['CpG'])
))

# Calculate overlaps with high and low methylation
all_clocks_variable_high_overlap_methylated_cpgs = all_clocks_variable_methylated_cpgs.intersection(high_methylated_cpgs)
all_clocks_variable_low_overlap_methylated_cpgs = all_clocks_variable_methylated_cpgs.intersection(low_methylated_cpgs)
all_clocks_variable_no_overlap_methylated_cpgs = all_clocks_variable_methylated_cpgs - all_clocks_variable_high_overlap_methylated_cpgs - all_clocks_variable_low_overlap_methylated_cpgs

# Set the output folder
output_folder = 'Cross-Tissue Methylation Patterns'
os.makedirs(output_folder, exist_ok=True)

# Save the results to CSV files
pd.DataFrame(list(all_clocks_variable_methylated_cpgs), columns=['CpG']).to_csv(os.path.join(output_folder, 'all_clocks_variable_methylated_cpgs.csv'), index=False)
pd.DataFrame(list(all_clocks_variable_high_overlap_methylated_cpgs), columns=['CpG']).to_csv(os.path.join(output_folder, 'all_clocks_variable_high_overlap_methylated_cpgs.csv'), index=False)
pd.DataFrame(list(all_clocks_variable_low_overlap_methylated_cpgs), columns=['CpG']).to_csv(os.path.join(output_folder, 'all_clocks_variable_low_overlap_methylated_cpgs.csv'), index=False)
pd.DataFrame(list(all_clocks_variable_no_overlap_methylated_cpgs), columns=['CpG']).to_csv(os.path.join(output_folder, 'all_clocks_variable_no_overlap_methylated_cpgs.csv'), index=False)

# Print the result
print(f"\nNumber of CpGs consistently high variable methylation across all clocks: {len(all_clocks_variable_methylated_cpgs)}")
print(f'CpGs consistently high variable methylated across all clocks: {all_clocks_variable_methylated_cpgs}')

print(f"\nNumber of CpGs with high overlap: {len(all_clocks_variable_high_overlap_methylated_cpgs)}")
print(f"CpGs with high overlap: {all_clocks_variable_high_overlap_methylated_cpgs}")

print(f"\nNumber of CpGs with low overlap: {len(all_clocks_variable_low_overlap_methylated_cpgs)}")
print(f"CpGs with low overlap: {all_clocks_variable_low_overlap_methylated_cpgs}")

print(f"\nNumber of CpGs with no overlap: {len(all_clocks_variable_no_overlap_methylated_cpgs)}")
print(f"CpGs with no overlap: {all_clocks_variable_no_overlap_methylated_cpgs}")
# Out:
# Number of CpGs consistently high variable methylation across all clocks: 81
# ...

# %%
### CpGs with high variable methylation in all clocks (without overlaps between high and variable methylation)

# Get the set of CpGs with high variable methylation for each clock
variable_methylated_sets = {clock: set(df['CpG']) for clock, df in variable_methylation_cpgs.items()}

# Convert the CpGs to strings to avoid hash errors and exclude clock2_3
clock1 = set(str(cpg) for cpg in variable_methylated_sets['clock1'])
clock2 = set(str(cpg) for cpg in variable_methylated_sets['clock2'])
clock3 = set(str(cpg) for cpg in variable_methylated_sets['clock3'])
# clock2_3 = set(str(cpg) for cpg in variable_methylated_sets['clock2_3']) # Not used at it already is an overlap of two clocks

# Find the intersection of all sets
all_clocks_variable_methylated_cpgs = set.intersection(clock1, clock2, clock3) #instead of set.intersection(*variable_methylated_sets.values()) as this pulls all the clocks and I dont want to include clock2_3

# Convert the result to a list if needed
all_clocks_variable_methylated_cpgs = list(all_clocks_variable_methylated_cpgs)

# Set the output folder
output_folder = 'Cross-Tissue Methylation Patterns'
os.makedirs(output_folder, exist_ok=True)

# save the list to a csv file
all_clocks_variable_methylated_cpgs_df = pd.DataFrame(all_clocks_variable_methylated_cpgs, columns=['CpG'])
all_clocks_variable_methylated_cpgs_df.to_csv(os.path.join(output_folder, 'all_clocks_variable_methylated_cpgs.csv'), index=False)

# Print the result
print(f"\nNumber of CpGs consistently high variable methylation across all clocks: {len(all_clocks_variable_methylated_cpgs)}")
print("CpGs consistently high variable methylation across all clocks:")
print(all_clocks_variable_methylated_cpgs)
# Out:
# Number of CpGs consistently high variable methylation across all clocks: 81
# CpGs consistently high variable methylation across all clocks:
# ...

# %%
### Venn diagram of CpGs with high variable methylation across clocks

# Select the CpGs with high variable methylation for each clock
venn = venn3([variable_methylated_sets['clock1'], variable_methylated_sets['clock2'], variable_methylated_sets['clock3']],
        ('Clock1', 'Clock2', 'Clock3'))

# Apply the viridis colormap
viridis = colormaps.get_cmap('viridis')  # Get the viridis colormap

# Generate 7 colors from the colormap
colors = [viridis(i / 6) for i in range(7)]

# Set colors for the Venn diagram areas
for i, patch in enumerate(venn.patches):
    if patch is not None:
        patch.set_color(colors[i])
        patch.set_edgecolor('black')  # Optionally add a border for better visualization

plt.title('Variably Methylated CpGs')
plt.show()

# %%
# Summary of CpGs with high variable methylation
print(f'Number of CpGs with high variable methylation in Clock 1: {len(variable_methylated_sets["clock1"])}')
print(f'Number of CpGs with high variable methylation of Clock 1 that Overlap with Clock 2: {len(variable_methylated_sets["clock1"].intersection(variable_methylated_sets["clock2"]))}')
print(f'Number of CpGs with high variable methylation of Clock 1 that Overlap with Clock 3: {len(variable_methylated_sets["clock1"].intersection(variable_methylated_sets["clock3"]))}')

print(f'\nNumber of CpGs with high variable methylation in Clock 2: {len(variable_methylated_sets["clock2"])}')
print(f'Number of CpGs with high variable methylation of Clock 2 that Overlap with Clock 1: {len(variable_methylated_sets["clock2"].intersection(variable_methylated_sets["clock1"]))}')
print(f'Number of CpGs with high variable methylation of Clock 2 that Overlap with Clock 3: {len(variable_methylated_sets["clock2"].intersection(variable_methylated_sets["clock3"]))}')

print(f'\nNumber of CpGs with high variable methylation in Clock 3: {len(variable_methylated_sets["clock3"])}')
print(f'Number of CpGs with high variable methylation of Clock 3 that Overlap with Clock 1: {len(variable_methylated_sets["clock3"].intersection(variable_methylated_sets["clock1"]))}')
print(f'Number of CpGs with high variable methylation of Clock 3 that Overlap with Clock 2: {len(variable_methylated_sets["clock3"].intersection(variable_methylated_sets["clock2"]))}')
# Out:
# Number of CpGs with high variable methylation in Clock 1: 244
# Number of CpGs with high variable methylation of Clock 1 that Overlap with Clock 2: 112
# Number of CpGs with high variable methylation of Clock 1 that Overlap with Clock 3: 96
#
# Number of CpGs with high variable methylation in Clock 2: 561
# Number of CpGs with high variable methylation of Clock 2 that Overlap with Clock 1: 112
# Number of CpGs with high variable methylation of Clock 2 that Overlap with Clock 3: 297
#
# Number of CpGs with high variable methylation in Clock 3: 510
# Number of CpGs with high variable methylation of Clock 3 that Overlap with Clock 1: 96
# Number of CpGs with high variable methylation of Clock 3 that Overlap with Clock 2: 297

# %% [markdown]
# ### 2.5. Overlapped CpGs in All Tissues

# %%
# CpGs with high variable methylation that are not overlapped with high or low methylation

# Get the set of CpGs with high variable methylation that are not overlapped with high or low methylation for each clock
variable_methylated_sets = {clock: set(df['CpG']) for clock, df in variable_methylation_cpgs.items()}
high_methylated_sets = {clock: set(df['CpG']) for clock, df in high_methylation_cpgs.items()}
low_methylated_sets = {clock: set(df['CpG']) for clock, df in low_methylation_cpgs.items()}

# %% [markdown]
# ### 2.6. CpGs that are significantly differentially methylated between tissues in each clock

# %%
### Summary of significant CpGs from ANOVA

# Define the clocks and their file paths
clocks_sig_path = {
    'clock1': 'Cross-Tissue Methylation Patterns/clock1/clock1_significant_cpgs.csv',
    'clock2': 'Cross-Tissue Methylation Patterns/clock2/clock2_significant_cpgs.csv',
    'clock3': 'Cross-Tissue Methylation Patterns/clock3/clock3_significant_cpgs.csv',
    'clock2_3': 'Cross-Tissue Methylation Patterns/clock2_3/clock2_3_significant_cpgs.csv'
}

clock_significant_cpgs = {}

for clock_name, file_path in clocks_sig_path.items():
        
        # Load the significant CpGs for each clock
        significant_cpgs = pd.read_csv(file_path, index_col=0)

        # Store the significant CpGs in a dictionary
        clock_significant_cpgs[clock_name] = significant_cpgs

        # Rename columns from 0 to 'p-value'
        clock_significant_cpgs[clock_name].columns = ['p-value']

        print(f"\n{clock_name.upper()} CLOCK:")
        print(f"Number of significant CpGs: {clock_significant_cpgs.get(clock_name).shape[0]}")
        # print(f"Significant CpGs:\n{clock_significant_cpgs}")
# Out:
# CLOCK1 CLOCK:
# Number of significant CpGs: 42
#
# CLOCK2 CLOCK:
# Number of significant CpGs: 76
#
# CLOCK3 CLOCK:
# Number of significant CpGs: 59
#
# CLOCK2_3 CLOCK:
# Number of significant CpGs: 31

# %% [markdown]
# ### 2.7. CpGs that are significantly differentially methylated between tissues in all clocks

# %%
### CpGs that are significant in all clocks - vary significantly across tissues

significant_cpgs_all = {clock: set(df.index) for clock, df in clock_significant_cpgs.items()}

# Convert the CpGs to strings to avoid hash errors snd exclude clock2_3
clock1 = set(str(cpg) for cpg in clock_significant_cpgs['clock1'].index)
clock2 = set(str(cpg) for cpg in clock_significant_cpgs['clock2'].index)
clock3 = set(str(cpg) for cpg in clock_significant_cpgs['clock3'].index)
# clock2_3 = set(str(cpg) for cpg in clock_significant_cpgs['clock2_3'].index)

# Find the intersection of all sets
all_clocks_significant_cpgs = set.intersection(clock1, clock2, clock3) #instead of set.intersection(*significant_cpgs_all.values()) as this pulls all the clocks and I dont want to include clock2_3

# Select folder to save the results
folder_name = 'Cross-Tissue Methylation Patterns'
os.makedirs(folder_name, exist_ok=True)

# Save the results to a CSV file
anova_all_clocks_significant_cpgs = pd.DataFrame(all_clocks_significant_cpgs, columns=['CpG'])
anova_all_clocks_significant_cpgs.to_csv(os.path.join(folder_name, 'anova_all_clocks_significant_cpgs.csv'), index=False)


print(f"\nNumber of CpGs significant in all clocks: {len(all_clocks_significant_cpgs)}")
print(f"\nCpGs significant in all clocks:")
print(all_clocks_significant_cpgs)
# Out:
# Number of CpGs significant in all clocks: 17
#
# CpGs significant in all clocks:
# {'cg26072749', 'cg27228973', 'cg07875786', 'cg13188467', 'cg19981759', 'cg27201382', 'cg15437942', 'cg08938156', 'cg11516694', 'cg23510032', 'cg07323940', 'cg14361875', 'cg23087015', 'cg11084334', 'cg11235379', 'cg05844902', 'cg23415880'}

# %%
### Venn diagram of significant CpGs across clocks

# Select the CpGs that are significant in each clock
venn = venn3([set(clock_significant_cpgs['clock1'].index), set(clock_significant_cpgs['clock2'].index), set(clock_significant_cpgs['clock3'].index)],
      ('Clock1', 'Clock2', 'Clock3'))

# Apply the viridis colormap
viridis = colormaps.get_cmap('viridis')  # Get the viridis colormap

# Generate 7 colors from the colormap
colors = [viridis(i / 6) for i in range(7)]

# Set colors for the Venn diagram areas
for i, patch in enumerate(venn.patches):
    if patch is not None:
        patch.set_color(colors[i])
        patch.set_edgecolor('black')  # Optionally add a border for better visualization

plt.title('Significant CpGs Overlap')
plt.show()

# %%
### Density plot of mean methylation levels for significant CpGs

# Load the mean methylation levels for significant CpGs
clock1_mean_methylation = pd.read_csv('Cross-Tissue Methylation Patterns/clock1/clock1_mean_methylation.csv', index_col=0)
clock2_mean_methylation = pd.read_csv('Cross-Tissue Methylation Patterns/clock2/clock2_mean_methylation.csv', index_col=0)
clock3_mean_methylation = pd.read_csv('Cross-Tissue Methylation Patterns/clock3/clock3_mean_methylation.csv')

# Load the significant CpGs for each clock
clock1_significant_cpgs = pd.read_csv('Cross-Tissue Methylation Patterns/clock1/clock1_significant_cpgs.csv', index_col=0)
clock2_significant_cpgs = pd.read_csv('Cross-Tissue Methylation Patterns/clock2/clock2_significant_cpgs.csv', index_col=0)
clock3_significant_cpgs = pd.read_csv('Cross-Tissue Methylation Patterns/clock3/clock3_significant_cpgs.csv', index_col=0)

# Define the clocks and their mean methylation levels
clocks_mean_meth = {
    'Clock1': clock1_mean_methylation,
    'Clock2': clock2_mean_methylation,
    'Clock3': clock3_mean_methylation
}

# Define the clocks and their significant CpGs
clocks_sig = {
    'Clock1': clock1_significant_cpgs,
    'Clock2': clock2_significant_cpgs,
    'Clock3': clock3_significant_cpgs
}

# Set the output folder
output_folder = 'Cross-Tissue Methylation Patterns'
os.makedirs(output_folder, exist_ok=True)

# Create a density plot for each clock
for clock, mean_methylation in clocks_mean_meth.items():
    # Filter the mean methylation levels for significant CpGs
    significant_cpgs = clocks_sig[clock].index
    mean_methylation_sig = mean_methylation[mean_methylation.index.isin(significant_cpgs)]
    
    # Create the density plot
    plt.figure(figsize=(12, 8))
    sns.kdeplot(data=mean_methylation_sig, fill=True, common_norm=False, palette='viridis')
    plt.title(f'Density Plot of Mean Methylation Levels for Significant CpGs - {clock}',
              fontsize=15,
              fontweight='bold',
              pad=20)
    plt.xlabel('Mean Methylation Level')
    plt.ylabel('Density')
    plt.savefig(os.path.join(output_folder, f'{clock}_density_plot.png'), dpi=300, bbox_inches='tight')
    plt.show()
    plt.close()
# Out:
# C:\Users\Catia Antunes\AppData\Local\Temp\ipykernel_16660\585224769.py:39: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.kdeplot(data=mean_methylation_sig, fill=True, common_norm=False, palette='viridis')

# %% [markdown]
# ### FINAL SAVINGS

# %%
### Final Excel file with each clock CpGs and patterns across tissues

# Define the destination folder
destination_folder = 'Cross-Tissue Methylation Patterns/Complete'

# Ensure the folder exists; if not, create it
os.makedirs(destination_folder, exist_ok=True)

# Define the full path for the Excel file
file_path = os.path.join(destination_folder, 'Crosstissue_clocks_patterns.xlsx')

# Initialize the dataframe to store the summary results
clock_results_cpgs = pd.DataFrame(columns=['Clock', 'High Methylation', 'Low Methylation', 'Variable Methylation', 'High and Variable Overlap', 'Low and Variable Overlap', 'Variable No Overlap'])

# Create a writer object to save the data into an Excel file
with pd.ExcelWriter(file_path) as writer:
    
    for clock_name, results in analysis_results.items():
        high_methylation = results['high_methylation']
        low_methylation = results['low_methylation']
        variable_cpgs = results['variable_cpgs']
        mean_methylation = results['mean_methylation']

        # Identify overlapping CpGs
        high_variable_overlap = set(high_methylation.index).intersection(set(variable_cpgs.index))
        low_variable_overlap = set(low_methylation.index).intersection(set(variable_cpgs.index))
        variable_no_overlap = set(variable_cpgs.index) - set(high_methylation.index) - set(low_methylation.index)

        # Create a new row for the summary DataFrame
        new_row = pd.DataFrame({
            'Clock': [clock_name],
            'High Methylation': [len(high_methylation)],
            'Low Methylation': [len(low_methylation)],
            'Variable Methylation': [len(variable_cpgs)],
            'High and Variable Overlap': [len(high_variable_overlap)],
            'Low and Variable Overlap': [len(low_variable_overlap)],
            'Variable No Overlap': [len(variable_no_overlap)]
        })

        # Concatenate the new row with the existing summary dataframe
        clock_results_cpgs = pd.concat([clock_results_cpgs, new_row], ignore_index=True)

        # Save the detailed lists to separate sheets in the Excel file
        high_methylation.to_excel(writer, sheet_name=f'{clock_name}_High Methylation')
        low_methylation.to_excel(writer, sheet_name=f'{clock_name}_Low Methylation')
        variable_cpgs.to_excel(writer, sheet_name=f'{clock_name}_Variable Methylation')
        pd.DataFrame(high_variable_overlap).to_excel(writer, sheet_name=f'{clock_name}_High_Variable_Overlap', header=['CpG ID'])
        pd.DataFrame(low_variable_overlap).to_excel(writer, sheet_name=f'{clock_name}_Low_Variable_Overlap', header=['CpG ID'])
        pd.DataFrame(variable_no_overlap).to_excel(writer, sheet_name=f'{clock_name}_Variable_No_Overlap', header=['CpG ID'])

    # Save the summary dataframe as a separate sheet
    clock_results_cpgs.to_excel(writer, sheet_name='Summary', index=False)

# Confirm the file was saved
print(f"File saved to: {file_path}")
# Out:
# File saved to: Cross-Tissue Methylation Patterns/Complete\Crosstissue_clocks_patterns.xlsx

# %%
### Final Excel file with all clock CpGs and patterns across tissues

# Define the destination folder
destination_folder = 'Cross-Tissue Methylation Patterns/Complete'

# Ensure the folder exists; if not, create it
os.makedirs(destination_folder, exist_ok=True)

# Define the full path for the Excel file
file_path = os.path.join(destination_folder, 'Crosstissue_all_clocks_patterns.xlsx')

# Initialize the dataframe to store the summary results
all_clocks_results_cpgs = pd.DataFrame(columns=['High Methylation', 'Low Methylation', 'Variable Methylation', 'High and Variable Overlap', 'Low and Variable Overlap', 'Variable No Overlap'])

# Create a writer object to save the data into an Excel file
with pd.ExcelWriter(file_path) as writer:
    
    # Identify overlapping CpGs
    high_variable_overlap = set.intersection(
        set(high_methylation_cpgs['clock1']['CpG']),
        set(high_methylation_cpgs['clock2']['CpG']),
        set(high_methylation_cpgs['clock3']['CpG'])
    )

    low_variable_overlap = set.intersection(
        set(low_methylation_cpgs['clock1']['CpG']),
        set(low_methylation_cpgs['clock2']['CpG']),
        set(low_methylation_cpgs['clock3']['CpG'])
    )

    variable_no_overlap = set.intersection(
        set(variable_methylation_cpgs['clock1']['CpG']),
        set(variable_methylation_cpgs['clock2']['CpG']),
        set(variable_methylation_cpgs['clock3']['CpG'])
    )

    # Create a new row for the summary DataFrame
    new_row = pd.DataFrame({
        'High Methylation': [len(all_clocks_high_methylated_cpgs)],
        'Low Methylation': [len(all_clocks_low_methylated_cpgs)],
        'Variable Methylation': [len(all_clocks_variable_methylated_cpgs)],
        'High and Variable Overlap': [len(all_clocks_variable_high_overlap_methylated_cpgs)],
        'Low and Variable Overlap': [len(all_clocks_variable_low_overlap_methylated_cpgs)],
        'Variable No Overlap': [len(all_clocks_variable_no_overlap_methylated_cpgs)]
    })

    # Concatenate the new row with the existing summary dataframe
    all_clocks_results_cpgs = pd.concat([all_clocks_results_cpgs, new_row], ignore_index=True)

    # Save the detailed lists to separate sheets in the Excel file
    pd.DataFrame(all_clocks_high_methylated_cpgs).to_excel(writer, sheet_name='High Methylation', header=['CpG ID'])
    pd.DataFrame(all_clocks_low_methylated_cpgs).to_excel(writer, sheet_name='Low Methylation', header=['CpG ID'])
    pd.DataFrame(all_clocks_variable_methylated_cpgs).to_excel(writer, sheet_name='Variable Methylation', header=['CpG ID'])
    pd.DataFrame(all_clocks_variable_high_overlap_methylated_cpgs).to_excel(writer, sheet_name='High_Variable_Overlap', header=['CpG ID'])
    pd.DataFrame(all_clocks_variable_low_overlap_methylated_cpgs).to_excel(writer, sheet_name='Low_Variable_Overlap', header=['CpG ID'])
    pd.DataFrame(all_clocks_variable_no_overlap_methylated_cpgs).to_excel(writer, sheet_name='Variable_No_Overlap', header=['CpG ID'])

    # Save the summary dataframe as a separate sheet
    all_clocks_results_cpgs.to_excel(writer, sheet_name='Summary', index=False)

# Confirm the file was saved
print(f"File saved to: {file_path}")
# Out:
# File saved to: Cross-Tissue Methylation Patterns/Complete\Crosstissue_all_clocks_patterns.xlsx

# %%
all_clocks_results_cpgs = pd.DataFrame(columns=['High Methylation', 'Low Methylation', 'Variable Methylation', 'High and Variable Overlap', 'Low and Variable Overlap', 'Variable No Overlap'])
